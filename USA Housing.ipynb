# %%
import pandas as pd
data= pd.read_csv(r"C:\Users\walee\Downloads\usa market\usa_housing_kaggle.csv")
data
# Out:
#       Price  Bedrooms  Bathrooms  SquareFeet  YearBuilt  GarageSpaces  \
# 0    221958         1        1.9        4827       1979             2
# 1    771155         2        2.0        1035       1987             2
# 2    231932         1        3.0        2769       1982             1
# 3    465838         3        3.3        2708       1907             3
# 4    359178         4        3.4        1175       1994             2
# ..      ...       ...        ...         ...        ...           ...
# 295  862002         4        2.8        1129       1944             0
# 296  242483         3        2.4        4440       1988             2
# 297  758271         2        2.2        4694       1952             2
# 298  314835         5        2.0        4907       1941             3
# 299  501896         5        3.8        2141       1999             0
#
#      LotSize  ZipCode  CrimeRate  SchoolRating
# 0       1.45    82240      48.60             5
# ...

# %%
sr =data[(data['CrimeRate'] <= 80) & (data['SchoolRating'] >= 9)]
df= sr.set_index('SchoolRating')
df
# Out:
#                Price  Bedrooms  Bathrooms  SquareFeet  YearBuilt  \
# SchoolRating
# 9             744167         1        3.4        4330       1920
# 9             621430         4        2.3        3765       1979
# 9             141090         2        2.9        3698       1911
# 9             521909         1        3.3        2992       1984
# 9             600186         3        3.3        4833       1906
# 9             655839         5        2.1        3004       1993
# 9             339629         2        2.7        4028       1998
# 9             748531         5        2.8        3474       1942
# 9             415139         3        2.6        3805       1915
# 9             661353         1        3.5        4331       1998
# 9             664685         2        3.8        3856       2018
# 9             363160         2        1.1        4946       1917
# 9             320884         2        3.4        4167       1995
# ...

# %%
df1 = df.sort_values(by='CrimeRate', ascending=True)
df1
# Out:
#                Price  Bedrooms  Bathrooms  SquareFeet  YearBuilt  \
# SchoolRating
# 9             744167         1        3.4        4330       1920
# 9             320884         2        3.4        4167       1995
# 9             655839         5        2.1        3004       1993
# 9             325281         4        1.7        3828       1971
# 9             501896         5        3.8        2141       1999
# 9             661353         1        3.5        4331       1998
# 9             236330         2        2.8        4081       1904
# 9             613153         5        1.3        4650       1976
# 9             415139         3        2.6        3805       1915
# 9             314020         5        1.4        2865       1955
# 9             363160         2        1.1        4946       1917
# 9             502690         3        1.3        3373       2019
# 9             402918         4        3.3        1001       2010
# ...

# %%
df1.plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='SchoolRating'>
